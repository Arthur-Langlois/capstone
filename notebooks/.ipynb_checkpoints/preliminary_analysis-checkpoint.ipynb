# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

df = pd.read_csv('../archive/merged_master.csv')
df = df.drop(columns = ['sex', 'age', 'country-year', 'generation', 'Unnamed: 0'])
from scipy import stats

for i in df.columns:    
    df = df[df[i] != 'void']
    df.dropna(inplace = True)
df.reset_index(drop = True, inplace = True)    

df = df[['year','Population ages 65 and above (% of total population)',
       'Fertility rate, total (births per woman)',
       'Current health expenditure per capita (current US$)',
       'Literacy rate, adult total (% of people ages 15 and above)',
       'Rural population (% of total population)',
       'Unemployment, total (% of total labor force) (modeled ILO estimate)',
       'pct_mdisorder', 'pct_depression', 'suicides_no', 'population',
       'suicides/100k pop', 'HDI for year', 
       'gdp_per_capita ($)']].astype(float)

df = df.drop_duplicates()
df = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
# Out:
# /usr/local/lib/python3.9/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
sns.regplot(x='Population ages 65 and above (% of total population)', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='Population ages 65 and above (% of total population)', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='Fertility rate, total (births per woman)', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='Fertility rate, total (births per woman)', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='Current health expenditure per capita (current US$)', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='Current health expenditure per capita (current US$)', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='Literacy rate, adult total (% of people ages 15 and above)', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='Literacy rate, adult total (% of people ages 15 and above)', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='Rural population (% of total population)', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='Rural population (% of total population)', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='Unemployment, total (% of total labor force) (modeled ILO estimate)', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='Unemployment, total (% of total labor force) (modeled ILO estimate)', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='pct_mdisorder', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='pct_mdisorder', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='pct_depression', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='pct_depression', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='population', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='population', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='HDI for year', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='HDI for year', ylabel='suicides/100k pop'>

# %%
sns.regplot(x='gdp_per_capita ($)', y="suicides/100k pop", data=df, fit_reg = True)
# Out:
# <AxesSubplot:xlabel='gdp_per_capita ($)', ylabel='suicides/100k pop'>
